# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/hslu/pren/yolo_prototype/trainingWhiteQuarter'
# Out:
# images	labels

# %%
DATA_DIR = "/content/gdrive/My Drive/hslu/pren/yolo_prototype/trainingAllColors"

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.3/645.3 kB 9.0 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO


model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)

model.train(
    data="/content/gdrive/My Drive/hslu/pren/yolo_prototype/config.yaml",
    epochs=50,
    imgsz=640,
)
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 230MB/s]
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/hslu/pren/yolo_prototype'

# %%
import locale

locale.getpreferredencoding = lambda: "UTF-8"
